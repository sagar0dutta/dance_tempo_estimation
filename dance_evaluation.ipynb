# %%
import os
import pickle
from scipy import signal
import libfmp.b
import librosa
import numpy as np
import pandas as pd
from tqdm import tqdm
from load_djembe_marker import *
from foot_module import onset_calculations, onset_extraction, onset_filtering, utils, onset_plot
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter, argrelmin, argrelmax
from pydub import AudioSegment
from scipy.signal import find_peaks
from pydub.generators import Triangle
import mir_eval
from compute_tempo import *
from dance_evaluation import *

# %%
pkl_filelist = os.listdir(f"/itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2")

for filename in pkl_filelist:
    
    pickle_path = f'./output/motion_data_pkl/{filename.replace("_Dancers.csv", "_T.pkl")}'
        
    if os.path.isfile(pickle_path):
        with open(pickle_path, 'rb') as file:
            motion_data = pickle.load(file)
        print(f"Loaded {filename}")

    onset_filename = filename.replace("_Dancers.csv", "")
    danceanno_filename = filename

    drum_onsets_path = f"/itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/{onset_filename}.csv"
    dance_anno_path = f"/itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/{danceanno_filename}"

    print(pickle_path)
    print(drum_onsets_path)
    print(dance_anno_path)

    feet_length = len(motion_data['position']['SEGMENT_RIGHT_FOOT']) # size (n, 3)
    feet_onsets_path = f"./logs/{filename.replace("_Dancers.csv", "_T")}/onset_info/{filename.replace("_Dancers.csv", "_T")}_both_feet_onsets.csv"
    feet_df = pd.read_csv(feet_onsets_path, usecols=[1])
    feet_frames = feet_df.values.flatten()

    feet_onsets = np.zeros(feet_length)
    feet_onsets[feet_frames] = 1
    feet_onsets = np.reshape(feet_onsets, (-1, 1))
    #######################################################
    drum_df = pd.read_csv(drum_onsets_path)
    column_b = drum_df["J2"].dropna()
    drum_onsets = column_b.to_numpy()

    anno_df = pd.read_csv(dance_anno_path)
    category_df = anno_df.groupby('mocap')
    
    try:
        category_df = category_df.get_group('gr')
    except KeyError:
        # print("Group 'in' not found, continuing without it.")
        continue
    
    category_df = category_df.reset_index(drop=True)
    category_df
    
    row = 0
    start_f = np.round(category_df.iloc[row, 6]*240).astype(int)
    end_f = np.round(category_df.iloc[row, 7]*240).astype(int)
    start_t = start_f/240
    end_t = end_f/240
    ########################################################
    mocap_fps = 240
    window_size = 240*10 #corresponding to 10 sec
    hop_size = 240*5
    tempi_range = np.arange(60,200,1)

    tempo_json_two_sensor = main_two_sensor_feet(feet_onsets, mocap_fps, window_size, hop_size, tempi_range)
    feet_sensor_onsets = tempo_json_two_sensor["feet_sensor_onsets"]
    ########################################################
    drum_ref = drum_onsets[(drum_onsets >= start_t) & (drum_onsets <= end_t)]
    half_beats = (drum_ref[:-1] + drum_ref[1:]) / 2
    drum_subref = np.sort(np.concatenate((drum_ref, half_beats)))
    # raw onsets
    onsets_frm = np.where(feet_sensor_onsets > 0)[0]     # Frames idx of onsets
    onsets_t = onsets_frm/240
    dance_onset = onsets_t[(onsets_t >= start_t) & (onsets_t <= end_t)]

    print("\n")
    # evaluate_dance_onsets(drum_ref, dance_onset, tolerance=0.1)
    results = evaluate_dance_onsets_with_half_beats(drum_ref, dance_onset, tolerance=0.1)
    print("\nEvaluation Results:")
    for key, value in results.items():
        print(f"{key}: {value}")
    print("-"*40)

# Also check if the unmatched dance onset is half of its previous and next dance onset and not only with drum
# Out:
# Loaded BKO_E1_D1_08_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_08_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_08_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_08_Suku_Dancers.csv
# Loaded BKO_E3_D5_03_Wasulunka_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D5_03_Wasulunka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D5_03_Wasulunka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D5_03_Wasulunka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 85.36105439019863
# Computing weighted method...
# Global Bpm: 110.73134328358209
#
#
#
# Evaluation Results:
# Total Onsets: 62
# Total Primary Match: 46
# Total Secondary Match: 16
# Primary Matching Rate: 0.7419354838709677
# Secondary Matching Rate: 0.25806451612903225
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.056007246456521304
# Average Time Difference (Secondary): 0.04803124999999975
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E2_D4_05_Sandia_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D4_05_Sandia_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D4_05_Sandia.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D4_05_Sandia_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 71.77048887300028
# Computing weighted method...
# Global Bpm: 98.56521739130434
#
#
#
# Evaluation Results:
# Total Onsets: 58
# Total Primary Match: 51
# Total Secondary Match: 4
# Primary Matching Rate: 0.8793103448275862
# Secondary Matching Rate: 0.06896551724137931
# Overall Matching Rate: 0.9482758620689655
# Average Time Difference (Primary): 0.035356209104575216
# Average Time Difference (Secondary): 0.021000000291666154
# Number of Unmatched Dance Onsets: 3
# ----------------------------------------
# Loaded BKO_E2_D4_01_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D4_01_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D4_01_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D4_01_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 81.76485290442095
# Computing weighted method...
# Global Bpm: 96.83928571428571
#
#
#
# Evaluation Results:
# Total Onsets: 52
# Total Primary Match: 52
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.026641025352563637
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E2_D4_03_Wasulunka_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D4_03_Wasulunka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D4_03_Wasulunka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D4_03_Wasulunka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 76.97356989787053
# Computing weighted method...
# Global Bpm: 103.37209302325581
#
#
#
# Evaluation Results:
# Total Onsets: 3
# Total Primary Match: 2
# Total Secondary Match: 1
# Primary Matching Rate: 0.6666666666666666
# Secondary Matching Rate: 0.3333333333333333
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.050583333499996996
# Average Time Difference (Secondary): 0.07333333316666568
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D2_04_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D2_04_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D2_04_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D2_04_Maraka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 107.35848676117688
# Computing weighted method...
# Global Bpm: 126.17073170731707
#
#
#
# Evaluation Results:
# Total Onsets: 66
# Total Primary Match: 50
# Total Secondary Match: 13
# Primary Matching Rate: 0.7575757575757576
# Secondary Matching Rate: 0.19696969696969696
# Overall Matching Rate: 0.9545454545454546
# Average Time Difference (Primary): 0.05034333366000027
# Average Time Difference (Secondary): 0.06717948692307811
# Number of Unmatched Dance Onsets: 3
# ----------------------------------------
# Loaded BKO_E3_D5_01_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D5_01_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D5_01_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D5_01_Maraka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 74.08998077847188
# Computing weighted method...
# Global Bpm: 101.36363636363636
#
#
#
# Evaluation Results:
# Total Onsets: 48
# Total Primary Match: 41
# Total Secondary Match: 7
# Primary Matching Rate: 0.8541666666666666
# Secondary Matching Rate: 0.14583333333333334
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.042154471691056884
# Average Time Difference (Secondary): 0.02990476169047542
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E3_D6_02_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D6_02_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D6_02_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D6_02_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 85.62375863047384
# Computing weighted method...
# Global Bpm: 98.6923076923077
#
#
#
# Evaluation Results:
# Total Onsets: 35
# Total Primary Match: 33
# Total Secondary Match: 2
# Primary Matching Rate: 0.9428571428571428
# Secondary Matching Rate: 0.05714285714285714
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.04981313139393875
# Average Time Difference (Secondary): 0.01733333366666656
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E2_D4_06_Manjanin_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D4_06_Manjanin_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D4_06_Manjanin.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D4_06_Manjanin_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 72.76649995096597
# Computing weighted method...
# Global Bpm: 106.76
#
#
#
# Evaluation Results:
# Total Onsets: 83
# Total Primary Match: 78
# Total Secondary Match: 5
# Primary Matching Rate: 0.9397590361445783
# Secondary Matching Rate: 0.060240963855421686
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.026299145162393317
# Average Time Difference (Secondary): 0.055499999766666974
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D1_01_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_01_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_01_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_01_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 94.88878156352801
# Computing weighted method...
# Global Bpm: 111.31868131868131
#
#
#
# Evaluation Results:
# Total Onsets: 38
# Total Primary Match: 26
# Total Secondary Match: 12
# Primary Matching Rate: 0.6842105263157895
# Secondary Matching Rate: 0.3157894736842105
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.06483974379487133
# Average Time Difference (Secondary): 0.02058333320833287
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E3_D5_13_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D5_13_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D5_13_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D5_13_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 101.06657173371306
# Computing weighted method...
# Global Bpm: 110.05172413793103
#
#
#
# Evaluation Results:
# Total Onsets: 36
# Total Primary Match: 34
# Total Secondary Match: 2
# Primary Matching Rate: 0.9444444444444444
# Secondary Matching Rate: 0.05555555555555555
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.028142156950980362
# Average Time Difference (Secondary): 0.021166666583333438
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D5_05_Sandia_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D5_05_Sandia_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D5_05_Sandia.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D5_05_Sandia_Dancers.csv
# Loaded BKO_E1_D1_02_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_02_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_02_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_02_Maraka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 91.0907082536553
# Computing weighted method...
# Global Bpm: 109.58571428571429
#
#
#
# Evaluation Results:
# Total Onsets: 37
# Total Primary Match: 22
# Total Secondary Match: 15
# Primary Matching Rate: 0.5945945945945946
# Secondary Matching Rate: 0.40540540540540543
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.06420454577272672
# Average Time Difference (Secondary): 0.05857777751111139
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E2_D3_05_Sandia_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_05_Sandia_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_05_Sandia.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_05_Sandia_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 124.09026830638044
# Computing weighted method...
# Global Bpm: 129.13888888888889
#
#
#
# Evaluation Results:
# Total Onsets: 69
# Total Primary Match: 61
# Total Secondary Match: 2
# Primary Matching Rate: 0.8840579710144928
# Secondary Matching Rate: 0.028985507246376812
# Overall Matching Rate: 0.9130434782608695
# Average Time Difference (Primary): 0.04018306026229514
# Average Time Difference (Secondary): 0.09624999975000215
# Number of Unmatched Dance Onsets: 6
# ----------------------------------------
# Loaded BKO_E2_D3_14_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_14_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_14_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_14_Maraka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 82.32002983961209
# Computing weighted method...
# Global Bpm: 103.5223880597015
#
#
#
# Evaluation Results:
# Total Onsets: 63
# Total Primary Match: 61
# Total Secondary Match: 1
# Primary Matching Rate: 0.9682539682539683
# Secondary Matching Rate: 0.015873015873015872
# Overall Matching Rate: 0.9841269841269841
# Average Time Difference (Primary): 0.03100819687978127
# Average Time Difference (Secondary): 0.051166666500000346
# Number of Unmatched Dance Onsets: 1
# ----------------------------------------
# Loaded BKO_E3_D6_03_Wasulunka_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D6_03_Wasulunka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D6_03_Wasulunka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D6_03_Wasulunka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 83.40357283011141
# Computing weighted method...
# Global Bpm: 114.60416666666667
#
#
#
# Evaluation Results:
# Total Onsets: 46
# Total Primary Match: 30
# Total Secondary Match: 16
# Primary Matching Rate: 0.6521739130434783
# Secondary Matching Rate: 0.34782608695652173
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.04725555564444501
# Average Time Difference (Secondary): 0.03180208332291601
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D5_01_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D5_01_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D5_01_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D5_01_Maraka_Dancers.csv
# Loaded BKO_E3_D5_04_Dansa_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D5_04_Dansa_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D5_04_Dansa.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D5_04_Dansa_Dancers.csv
# Loaded BKO_E2_D4_04_Dansa_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D4_04_Dansa_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D4_04_Dansa.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D4_04_Dansa_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 86.36856240870753
# Computing weighted method...
# Global Bpm: 111.09433962264151
#
#
#
# Evaluation Results:
# Total Onsets: 25
# Total Primary Match: 16
# Total Secondary Match: 3
# Primary Matching Rate: 0.64
# Secondary Matching Rate: 0.12
# Overall Matching Rate: 0.76
# Average Time Difference (Primary): 0.053770833666666684
# Average Time Difference (Secondary): 0.027944444166667637
# Number of Unmatched Dance Onsets: 6
# ----------------------------------------
# Loaded BKO_E3_D6_01_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D6_01_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D6_01_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D6_01_Maraka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 89.20958559512776
# Computing weighted method...
# Global Bpm: 108.83783783783784
#
#
#
# Evaluation Results:
# Total Onsets: 50
# Total Primary Match: 45
# Total Secondary Match: 5
# Primary Matching Rate: 0.9
# Secondary Matching Rate: 0.1
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.028103703859258804
# Average Time Difference (Secondary): 0.042233333033333056
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D2_06_Dansa_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D2_06_Dansa_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D2_06_Dansa.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D2_06_Dansa_Dancers.csv
# Loaded BKO_E2_D4_02_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D4_02_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D4_02_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D4_02_Maraka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 110.07202693180929
# Computing weighted method...
# Global Bpm: 115.38095238095238
#
#
#
# Evaluation Results:
# Total Onsets: 66
# Total Primary Match: 66
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.025540404085858125
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E2_D4_12_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D4_12_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D4_12_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D4_12_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 96.23603039785426
# Computing weighted method...
# Global Bpm: 133.94545454545454
#
#
#
# Evaluation Results:
# Total Onsets: 63
# Total Primary Match: 63
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.01983597898941808
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D1_07_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_07_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_07_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_07_Suku_Dancers.csv
# Loaded BKO_E1_D5_02_Dansa_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D5_02_Dansa_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D5_02_Dansa.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D5_02_Dansa_Dancers.csv
# Loaded BKO_E2_D3_02_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_02_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_02_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_02_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 69.18086562268212
# Computing weighted method...
# Global Bpm: 109.50632911392405
#
#
#
# Evaluation Results:
# Total Onsets: 74
# Total Primary Match: 74
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.024630630626126415
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D2_05_Wasulunka_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D2_05_Wasulunka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D2_05_Wasulunka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D2_05_Wasulunka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 100.02241330127552
# Computing weighted method...
# Global Bpm: 120.17283950617283
#
#
#
# Evaluation Results:
# Total Onsets: 20
# Total Primary Match: 18
# Total Secondary Match: 1
# Primary Matching Rate: 0.9
# Secondary Matching Rate: 0.05
# Overall Matching Rate: 0.95
# Average Time Difference (Primary): 0.052249999962963756
# Average Time Difference (Secondary): 0.005166666166658729
# Number of Unmatched Dance Onsets: 1
# ----------------------------------------
# Loaded BKO_E1_D1_04_Dansa_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_04_Dansa_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_04_Dansa.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_04_Dansa_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 94.88961866382124
# Computing weighted method...
# Global Bpm: 113.075
#
#
#
# Evaluation Results:
# Total Onsets: 44
# Total Primary Match: 25
# Total Secondary Match: 16
# Primary Matching Rate: 0.5681818181818182
# Secondary Matching Rate: 0.36363636363636365
# Overall Matching Rate: 0.9318181818181818
# Average Time Difference (Primary): 0.06706000017333565
# Average Time Difference (Secondary): 0.033364583260419245
# Number of Unmatched Dance Onsets: 3
# ----------------------------------------
# Loaded BKO_E1_D2_03_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D2_03_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D2_03_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D2_03_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 76.06802831800798
# Computing weighted method...
# Global Bpm: 103.59016393442623
#
#
#
# Evaluation Results:
# Total Onsets: 55
# Total Primary Match: 28
# Total Secondary Match: 25
# Primary Matching Rate: 0.509090909090909
# Secondary Matching Rate: 0.45454545454545453
# Overall Matching Rate: 0.9636363636363636
# Average Time Difference (Primary): 0.07374404777381015
# Average Time Difference (Secondary): 0.029879999793334378
# Number of Unmatched Dance Onsets: 2
# ----------------------------------------
# Loaded BKO_E2_D3_06_Manjanin_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_06_Manjanin_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_06_Manjanin.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_06_Manjanin_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 97.80335647131183
# Computing weighted method...
# Global Bpm: 122.26785714285714
#
#
#
# Evaluation Results:
# Total Onsets: 59
# Total Primary Match: 59
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.028324858909604466
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D1_06_Manjanin_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_06_Manjanin_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_06_Manjanin.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_06_Manjanin_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 95.97963614584113
# Computing weighted method...
# Global Bpm: 110.43
#
#
#
# Evaluation Results:
# Total Onsets: 21
# Total Primary Match: 20
# Total Secondary Match: 1
# Primary Matching Rate: 0.9523809523809523
# Secondary Matching Rate: 0.047619047619047616
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.06026666698333187
# Average Time Difference (Secondary): 0.0011666673333294852
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E2_D3_13_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_13_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_13_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_13_Suku_Dancers.csv
# Loaded BKO_E2_D3_11_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_11_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_11_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_11_Suku_Dancers.csv
# Loaded BKO_E3_D6_04_Sandia_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D6_04_Sandia_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D6_04_Sandia.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D6_04_Sandia_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 78.51884898505465
# Computing weighted method...
# Global Bpm: 92.84615384615384
#
#
#
# Evaluation Results:
# Total Onsets: 48
# Total Primary Match: 39
# Total Secondary Match: 6
# Primary Matching Rate: 0.8125
# Secondary Matching Rate: 0.125
# Overall Matching Rate: 0.9375
# Average Time Difference (Primary): 0.05211538469230685
# Average Time Difference (Secondary): 0.062083333555550034
# Number of Unmatched Dance Onsets: 3
# ----------------------------------------
# Loaded BKO_E2_D3_01_Maraka_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_01_Maraka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_01_Maraka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_01_Maraka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 90.01890250887845
# Computing weighted method...
# Global Bpm: 105.03448275862068
#
#
#
# Evaluation Results:
# Total Onsets: 70
# Total Primary Match: 70
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.02777619047142836
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E3_D6_06_Manjanin_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D6_06_Manjanin_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D6_06_Manjanin.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D6_06_Manjanin_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 101.27560967458028
# Computing weighted method...
# Global Bpm: 119.94594594594595
#
#
#
# Evaluation Results:
# Total Onsets: 60
# Total Primary Match: 60
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.04459444458889017
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E3_D5_05_Sandia_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D5_05_Sandia_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D5_05_Sandia.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D5_05_Sandia_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 87.9948347524313
# Computing weighted method...
# Global Bpm: 106.65573770491804
#
#
#
# Evaluation Results:
# Total Onsets: 38
# Total Primary Match: 35
# Total Secondary Match: 2
# Primary Matching Rate: 0.9210526315789473
# Secondary Matching Rate: 0.05263157894736842
# Overall Matching Rate: 0.9736842105263158
# Average Time Difference (Primary): 0.04800476192380927
# Average Time Difference (Secondary): 0.05125000033333649
# Number of Unmatched Dance Onsets: 1
# ----------------------------------------
# Loaded BKO_E1_D1_03_Wasulunka_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_03_Wasulunka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_03_Wasulunka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_03_Wasulunka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 95.63371225447972
# Computing weighted method...
# Global Bpm: 127.3970588235294
#
#
#
# Evaluation Results:
# Total Onsets: 65
# Total Primary Match: 33
# Total Secondary Match: 28
# Primary Matching Rate: 0.5076923076923077
# Secondary Matching Rate: 0.4307692307692308
# Overall Matching Rate: 0.9384615384615385
# Average Time Difference (Primary): 0.055267676919192245
# Average Time Difference (Secondary): 0.0363571428273818
# Number of Unmatched Dance Onsets: 4
# ----------------------------------------
# Loaded BKO_E1_D1_05_Sandia_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D1_05_Sandia_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D1_05_Sandia.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D1_05_Sandia_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 97.63455298198501
# Computing weighted method...
# Global Bpm: 109.36036036036036
#
#
#
# Evaluation Results:
# Total Onsets: 46
# Total Primary Match: 41
# Total Secondary Match: 1
# Primary Matching Rate: 0.8913043478260869
# Secondary Matching Rate: 0.021739130434782608
# Overall Matching Rate: 0.9130434782608695
# Average Time Difference (Primary): 0.044825203203251396
# Average Time Difference (Secondary): 0.0004999998333374833
# Number of Unmatched Dance Onsets: 4
# ----------------------------------------
# Loaded BKO_E1_D2_07_Sandia_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D2_07_Sandia_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D2_07_Sandia.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D2_07_Sandia_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 96.56008341758015
# Computing weighted method...
# Global Bpm: 115.78980891719745
#
#
#
# Evaluation Results:
# Total Onsets: 37
# Total Primary Match: 32
# Total Secondary Match: 5
# Primary Matching Rate: 0.8648648648648649
# Secondary Matching Rate: 0.13513513513513514
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.051848958197918016
# Average Time Difference (Secondary): 0.06790000033332717
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E2_D3_03_Wasulunka_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_03_Wasulunka_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_03_Wasulunka.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_03_Wasulunka_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 81.59878468425958
# Computing weighted method...
# Global Bpm: 99.54166666666667
#
#
#
# Evaluation Results:
# Total Onsets: 27
# Total Primary Match: 22
# Total Secondary Match: 5
# Primary Matching Rate: 0.8148148148148148
# Secondary Matching Rate: 0.18518518518518517
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.050219696757576156
# Average Time Difference (Secondary): 0.03570000013333328
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E1_D5_04_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E1_D5_04_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E1_D5_04_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E1_D5_04_Suku_Dancers.csv
# Loaded BKO_E3_D5_06_Manjanin_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D5_06_Manjanin_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D5_06_Manjanin.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D5_06_Manjanin_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 96.38378128593382
# Computing weighted method...
# Global Bpm: 114.50649350649351
#
#
#
# Evaluation Results:
# Total Onsets: 63
# Total Primary Match: 58
# Total Secondary Match: 5
# Primary Matching Rate: 0.9206349206349206
# Secondary Matching Rate: 0.07936507936507936
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.033152298919540905
# Average Time Difference (Secondary): 0.020266666400000587
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E3_D6_10_Dansa_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D6_10_Dansa_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D6_10_Dansa.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D6_10_Dansa_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 91.2821608912875
# Computing weighted method...
# Global Bpm: 107.84946236559139
#
#
#
# Evaluation Results:
# Total Onsets: 54
# Total Primary Match: 38
# Total Secondary Match: 13
# Primary Matching Rate: 0.7037037037037037
# Secondary Matching Rate: 0.24074074074074073
# Overall Matching Rate: 0.9444444444444444
# Average Time Difference (Primary): 0.05661842116666673
# Average Time Difference (Secondary): 0.07621794857692357
# Number of Unmatched Dance Onsets: 3
# ----------------------------------------
# Loaded BKO_E2_D3_04_Dansa_Dancers.csv
# ./output/motion_data_pkl/BKO_E2_D3_04_Dansa_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E2_D3_04_Dansa.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E2_D3_04_Dansa_Dancers.csv
# Loaded BKO_E3_D5_02_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D5_02_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D5_02_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D5_02_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 76.05147427761872
# Computing weighted method...
# Global Bpm: 98.21428571428571
#
#
#
# Evaluation Results:
# Total Onsets: 55
# Total Primary Match: 54
# Total Secondary Match: 1
# Primary Matching Rate: 0.9818181818181818
# Secondary Matching Rate: 0.01818181818181818
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.03480555562345726
# Average Time Difference (Secondary): 0.03783333299999825
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------
# Loaded BKO_E3_D6_12_Suku_Dancers.csv
# ./output/motion_data_pkl/BKO_E3_D6_12_Suku_T.pkl
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/drum_onsets/BKO_E3_D6_12_Suku.csv
# /itf-fi-ml/home/sagardu/djembe_drive/sgr_pyspace/Dataset_V2/BKO_E3_D6_12_Suku_Dancers.csv
# Computing tempograms...
# Tempograms generated
# Computing max method...
# Global Bpm: 90.23014119498943
# Computing weighted method...
# Global Bpm: 96.36781609195403
#
#
#
# Evaluation Results:
# Total Onsets: 25
# Total Primary Match: 25
# Total Secondary Match: 0
# Primary Matching Rate: 1.0
# Secondary Matching Rate: 0.0
# Overall Matching Rate: 1.0
# Average Time Difference (Primary): 0.029926666479999257
# Average Time Difference (Secondary): None
# Number of Unmatched Dance Onsets: 0
# ----------------------------------------

# %%
drum_df = pd.read_csv(drum_onsets_path)
column_b = drum_df["J2"].dropna()
drum_onsets = column_b.to_numpy()

anno_df = pd.read_csv(dance_anno_path)
category_df = anno_df.groupby('mocap')
category_df = category_df.get_group('in')
category_df = category_df.reset_index(drop=True)
category_df

# %%
row = 0
start_f = np.round(category_df.iloc[row, 6]*240).astype(int)
end_f = np.round(category_df.iloc[row, 7]*240).astype(int)
start_t = start_f/240
end_t = end_f/240

drum_ref = drum_onsets[(drum_onsets >= start_t) & (drum_onsets <= end_t)]
half_beats = (drum_ref[:-1] + drum_ref[1:]) / 2
drum_subref = np.sort(np.concatenate((drum_ref, half_beats)))
# raw onsets
onsets_frm = np.where(feet_sensor_onsets > 0)[0]     # Frames idx of onsets
onsets_t = onsets_frm/240
dance_onset = onsets_t[(onsets_t >= start_t) & (onsets_t <= end_t)]

evaluate_dance_onsets(drum_ref, dance_onset, tolerance=0.1)

results = evaluate_dance_onsets_with_half_beats(drum_ref, dance_onset, tolerance=0.1)

print("\nEvaluation Results:")
for key, value in results.items():
    print(f"{key}: {value}")

print("-"*40)

# %% [markdown]
# ### From extracted feet onsets

# %%
novelty_length = len(feet_onsets)
time_axis = np.arange(novelty_length)/240

mocap_fps = 240
window_size = 240*10 #corresponding to 10 sec
hop_size = 240*5
tempi_range = np.arange(60,200,1)

tempo_json_two_sensor = main_two_sensor_feet(feet_onsets, mocap_fps, window_size, hop_size, tempi_range)
feet_sensor_onsets = tempo_json_two_sensor["feet_sensor_onsets"]
tempogram_ab = tempo_json_two_sensor["tempogram_ab"]
tempogram_raw = tempo_json_two_sensor["tempogram_raw"]
time_axis_seconds = tempo_json_two_sensor["time_axis_seconds"]
tempo_axis_bpm = tempo_json_two_sensor["tempo_axis_bpm"]

tempo_data_maxmethod = tempo_json_two_sensor["tempo_data_maxmethod"]
tempo_data_weightedkernel = tempo_json_two_sensor["tempo_data_weightedkernel"]
# tempo_data_combinedtempogram = tempo_json_two_sensor["tempo_data_combinedtempogram"]

# Max method
Aestimated_beat_pulse = tempo_data_maxmethod["estimated_beat_pulse"]
Atempo_curve = tempo_data_maxmethod["tempo_curve"]
Atempo_curve_time_axis = tempo_data_maxmethod["tempo_curve_time_axis"]
Aglobal_tempo_bpm = tempo_data_maxmethod["global_tempo_bpm"]

# Weighted method
Bestimated_beat_pulse = tempo_data_weightedkernel["estimated_beat_pulse"]
Btempo_curve = tempo_data_weightedkernel["tempo_curve"]
Btempo_curve_time_axis = tempo_data_weightedkernel["tempo_curve_time_axis"]
Bglobal_tempo_bpm = tempo_data_weightedkernel["global_tempo_bpm"]

# %%
# Per mode: drum onset and directional change onset plot

drum_ref = drum_onsets[(drum_onsets >= start_t) & (drum_onsets <= end_t)]
half_beats = (drum_ref[:-1] + drum_ref[1:]) / 2
drum_subref = np.sort(np.concatenate((drum_ref, half_beats)))
# raw onsets
onsets_frm = np.where(feet_sensor_onsets > 0)[0]     # Frames idx of onsets
onsets_t = onsets_frm/240
dance_onset = onsets_t[(onsets_t >= start_t) & (onsets_t <= end_t)]

# estimated beats
time = np.arange(novelty_length) / mocap_fps
peaks, _ = signal.find_peaks(Bestimated_beat_pulse)  # , prominence=0.02
peaks_t = time[peaks]
beat_estimated = peaks_t[(peaks_t >= start_t) & (peaks_t <= end_t)]

print("ref max ioi:", max(np.diff(drum_ref)))
print("ref min ioi:", min(np.diff(drum_ref)))
print("ref average ioi:", np.average(np.diff(drum_ref)))
# Plot figure
plt.figure(figsize=(40, 6), dpi=300)
# plt.vlines(x= drum_ref, ymin=0.0, ymax=1, color='r', linestyle='dotted', linewidth=0.9)
plt.vlines(x= drum_ref, ymin=0.0, ymax=1, color='b', linewidth=1.5,)
plt.vlines(x= dance_onset, ymin=0.0, ymax=1, color='r', linewidth=0.9,)
plt.xlabel('Time (seconds)')
plt.title(f'{file_name}')
plt.grid(True)
plt.show()

# %%
evaluate_dance_onsets(drum_ref, dance_onset, tolerance=0.1)

results = evaluate_dance_onsets_with_half_beats(drum_ref, dance_onset, tolerance=0.1)

print("\nEvaluation Results:")
for key, value in results.items():
    print(f"{key}: {value}")

print("-"*40)

# %%
plt.figure(figsize=(40, 6), dpi=200)
plt.plot(100*Aestimated_beat_pulse[start_f:end_f], linewidth=1, color = 'b')
plt.plot(Atempo_curve[start_f:end_f], linewidth=1, color = 'r')
# plt.plot(Atempo_curve_time_axis, Atempo_curve, linewidth=0.9, color = 'red')
# plt.vlines(x=np.array([start_f, end_f]), ymin=0.0, ymax=100, color='g', linewidth=1)

plt.xlabel('Time (seconds)')
plt.ylabel('Tempo (BPM)')
plt.title(f'Start:{start_t} End:{end_t}')
plt.grid(True)
plt.show()

# %%
# Tempogram

fig, axs = plt.subplots(1, 1, figsize=(5,5), dpi=100)
cax1 = axs.pcolormesh(time_axis_seconds, tempo_axis_bpm, tempogram_ab[0], shading='auto', cmap='magma')
axs.set_title('X-axis')
axs.set_xlabel('Time [s]')
axs.set_ylabel('Tempo [BPM]')
plt.colorbar(cax1, ax=axs, orientation='horizontal', label='Magnitude')
plt.show()

# %%
# Evaluate using mir_eval
# A significant increase in Recall with a slight decrease in Precision 
# may indicate that dancers are indeed synchronizing with subdivisions.


half_beats = (drum_ref[:-1] + drum_ref[1:]) / 2
combined_ref = np.sort(np.concatenate((drum_ref, half_beats)))

# scores = mir_eval.beat.evaluate(drum_reference, beat_estimated)
print("drum reference | ")
precision, recall, f_measure = mir_eval.onset.f_measure(drum_ref, beat_estimated, window= 0.2)
print(f'Precision: {precision}, Recall: {recall}, F-Measure: {f_measure}')

print("combined half-beat | ")
precision, recall, f_measure = mir_eval.onset.f_measure(combined_ref, beat_estimated, window= 0.2)
print(f'Precision: {precision}, Recall: {recall}, F-Measure: {f_measure}')

# dance onsets are less than reference onsets and thus the evaluation gives poor results.
# if dance onsets are not present for reference onsets than it should not be penalized.

# %%
onsets_val = drum_ref         # Onset values in seconds
window_size = 0.1  # 50ms window (±25ms)

# Plotting
plt.figure(figsize=(10, 2), dpi=300)
plt.vlines(x= dance_onset, ymin=0.0, ymax=1, color='b', linewidth=0.5,)
# Iterate through onsets and plot vertical lines and windows
for onset in onsets_val:
    window_start = onset - (window_size/2)  # Start of the window (25ms before)
    window_end = onset + (window_size/2)   # End of the window (25ms after)
    
    # Plot shaded window
    plt.axvspan(window_start, window_end, color='green', alpha=0.3)
    # Plot reference onset as a vertical line
    plt.axvline(onset, color='red', linestyle='--', linewidth=0.5)

# Customize the plot
plt.title("Visualization of Onsets with 50ms Windows")
plt.xlabel("Time (s)")
plt.xlim([min(onsets_val), max(onsets_val) + 1])  # Extend x-axis slightly beyond the last onset
plt.ylim([0, 1])  # Arbitrary y-axis for visualization
plt.yticks([])  # Hide y-axis ticks
plt.tight_layout()
plt.show()

# %%
time = np.arange(novelty_length) / mocap_fps
peaks, properties = signal.find_peaks(Aestimated_beat_pulse)  # , prominence=0.02
beat_peaks_sec = time[peaks]

click_duration = 50  # milliseconds
click_freq = 1200  # Hz
file_name ="maraka"

# Generate a single click sound
click = Triangle(click_freq).to_audio_segment(duration=click_duration)

onset_times = beat_peaks_sec  # kept_onsets/240   beat_peaks_sec
dN = novelty_length
total_duration = (dN/240)*1000  #  in milliseconds

audio = AudioSegment.silent(duration=total_duration)
for onset in onset_times:
    position = int(onset * 1000)  # Convert onset time to milliseconds
    audio = audio.overlay(click, position=position)

# Export the audio with clicks to a file
audio.export(os.path.join("/itf-fi-ml/home/sagardu/extract_feet_onset", f"{file_name}_Both_Foot_weighted.wav"), format="wav")
# audio.export(os.path.join("/itf-fi-ml/home/sagardu/extract_feet_onset", f"{file_name}_Bothhand_dir.wav"), format="wav")
